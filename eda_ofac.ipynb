# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional (for fraud logic)
from fuzzywuzzy import fuzz

# Better visualization
sns.set(style="whitegrid")
print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
df = pd.read_csv("sdn.csv")
df.head()
# Out:
#     36     AEROCARIBBEAN AIRLINES  -0-   CUBA -0- .1 -0- .2 -0- .3 -0- .4  \
# 0  173  ANGLO-CARIBBEAN CO., LTD.  -0-   CUBA   -0-    -0-    -0-    -0-
# 1  306     BANCO NACIONAL DE CUBA  -0-   CUBA   -0-    -0-    -0-    -0-
# 2  424         BOUTIQUE LA MAISON  -0-   CUBA   -0-    -0-    -0-    -0-
# 3  475               CASA DE CUBA  -0-   CUBA   -0-    -0-    -0-    -0-
# 4  480               CECOEX, S.A.  -0-   CUBA   -0-    -0-    -0-    -0-
#
#   -0- .5 -0- .6 -0- .7         -0- .8
# 0   -0-    -0-    -0-            -0-
# 1   -0-    -0-    -0-   a.k.a. 'BNC'.
# 2   -0-    -0-    -0-            -0-
# 3   -0-    -0-    -0-            -0-
# 4   -0-    -0-    -0-            -0-
